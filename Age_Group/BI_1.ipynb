# %%
import pandas as pd

pf = pd.read_excel('Demographic_and_BI_adoption.xlsx')

# %%
pf
# Out:
#                           COMPANY NAME  GENDER      AGE QUALIFICATION  \
# 0              DISCOUNT CENTER LIMITED    MALE     < 30       DIPLOMA
# 1                             CATS NET    MALE     < 30      BACHELOR
# 2                            INTER FIN    MALE   30 -39       MASTERS
# 3                              UNISOFT  FEMALE     < 30      BACHELOR
# 4               OPEN KITCHEN WARDROBES  FEMALE     < 30      BACHELOR
# 5   TANZANIA HORTICULTURAL ASSOCIATION  FEMALE   30 -39      BACHELOR
# 6                    ISCON COMMODITIES    MALE     < 30       DIPLOMA
# 7                            FLASH NET    MALE   30 -39      BACHELOR
# 8           PERFECT ENTERPRISE LIMITED    MALE  40 – 49           PhD
# 9                             NEO LIFE  FEMALE   30 -39      BACHELOR
# 10                            KIM SHOP  FEMALE     50 >           NaN
# 11                            NGELESHI    MALE  40 – 49       MASTERS
#
#                     ROLE EXISTENCE NO_EMPLOYEES
# ...
